# %%
import numpy as np

# XOR dataset
X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [1],
              [1],
              [0]])

# Activation function
def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
    return x*(1-x)

print("Enter the weights for the network\n")

# Input → Hidden weights
w1 = float(input("Weight w1 (x1 -> h1): "))
w2 = float(input("Weight w2 (x2 -> h1): "))
w3 = float(input("Weight w3 (x1 -> h2): "))
w4 = float(input("Weight w4 (x2 -> h2): "))

# Hidden → Output weights
w5 = float(input("Weight w5 (h1 -> output): "))
w6 = float(input("Weight w6 (h2 -> output): "))

# Weight matrices
W1 = np.array([[w1, w3],
               [w2, w4]])

W2 = np.array([[w5],
               [w6]])

learning_rate = 0.5
epochs = 5000

for epoch in range(epochs):

    # Forward propagation
    hidden = sigmoid(np.dot(X, W1))
    output = sigmoid(np.dot(hidden, W2))

    # Error
    error = y - output

    # Backpropagation
    d_output = error * sigmoid_derivative(output)
    d_hidden = d_output.dot(W2.T) * sigmoid_derivative(hidden)

    # Weight update
    W2 += hidden.T.dot(d_output) * learning_rate
    W1 += X.T.dot(d_hidden) * learning_rate

print("\nFinal Predictions:")
print(np.round(output,3))

print("\nRounded Predictions:")
print(np.round(output))
# Out:
# Enter the weights for the network
# Weight w1 (x1 -> h1):  1
# Weight w2 (x2 -> h1):  2
# Weight w3 (x1 -> h2):  3
# Weight w4 (x2 -> h2):  4
# Weight w5 (h1 -> output):  5
# Weight w6 (h2 -> output):  6
# Final Predictions:
# [[0.103]
#  [0.836]
#  [0.836]
#  [0.216]]
#
# Rounded Predictions:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
